# %%
#connect to google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_file = '/content/drive/My Drive/coding/SMSSpamCollection.txt'

# %%
import pandas as pd

data = pd.read_csv(data_file, sep="\t", header=None, names=["label", "sms"])
data.head()
# Out:
#   label                                                sms
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# #load stopwords and punctuation

# %%
import string
import nltk

nltk.download('stopwords')
nltk.download('punkt')

stopwords = nltk.corpus.stopwords.words('english')
punctuation = string.punctuation

print(stopwords[:5])#print the first 5 words
print(punctuation)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ['i', 'me', 'my', 'myself', 'we']
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
#pre-process sms content

def preprocess(sms):
  lowercase = "".join([char.lower() for char in sms if char not in punctuation])
  tokenize = nltk.tokenize.word_tokenize(lowercase)
  remove_stopwords = [word for word in tokenize if word not in stopwords]
  return remove_stopwords

data['processed'] = data['sms'].apply(lambda x: preprocess(x))
data.head()
# Out:
#   label  ...                                          processed
# 0   ham  ...  [go, jurong, point, crazy, available, bugis, n...
# 1   ham  ...                     [ok, lar, joking, wif, u, oni]
# 2  spam  ...  [free, entry, 2, wkly, comp, win, fa, cup, fin...
# 3   ham  ...      [u, dun, say, early, hor, u, c, already, say]
# 4   ham  ...  [nah, dont, think, goes, usf, lives, around, t...
#
# [5 rows x 3 columns]

# %%
def categorize_words():
    spam_words = []
    ham_words = []
    #handling messages associated with spam
    for sms in data["processed"][data['label'] == 'spam']:
        for word in sms:
            spam_words.append(word)
    #handling messages associated with ham
    for sms in data["processed"][data['label'] == 'ham']:
        for word in sms:
            ham_words.append(word)
    return spam_words, ham_words

spam_words, ham_words = categorize_words()

print(spam_words[:5])
print(ham_words[:5])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'processed'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-13de397e779b> in <module>()
#      12     return spam_words, ham_words
#      13
# ---> 14 spam_words, ham_words = categorize_words()
#      15
#      16 print(spam_words[:5])
#
# <ipython-input-29-13de397e779b> in categorize_words()
#       3     ham_words = []
#       4     #handling messages associated with spam
# ----> 5     for sms in data["processed"][data['label'] == 'spam']:
#       6         for word in sms:
#       7             spam_words.append(word)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 'processed'
